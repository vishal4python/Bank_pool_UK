# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


# df = pd.read_html('https://en.wikipedia.org/wiki/2018_Winter_Olympics_medal_table')
# print(df[1].to_dict())
# df[1].to_csv('wiki_olympic_2018.csv', index=False, header=False)
df = pd.read_csv('wiki_olympic_2018.csv')
df = df[:-1]
# df = pd.read_csv('wiki_olympic_2018.csv')
#l=['Gold','Silver','Bronze']
df.melt('NOC', var_name = 'cols', value_name = 'vals')
g1 = sns.factorplot(x="NOC",y = 'Gold', data = df[:-1])
g2  = sns.factorplot(x="NOC",y = 'Silver', data = df[:-1])
g3 = sns.factorplot(x="NOC",y = 'Bronze', data = df[:-1])
g = sns.jointplot(g1, g2, kind="line", size=7, space=0)
sns.factorplot(x='x',y='yModel',data=dataFrame,kind='point')
#df.plot(x='NOC',y=['Gold','Silver','Bronze'],ax=ax,kind='line')


#ax = sns.regplot(x="NOC",y = df['Silver'],data = df[:-1])
# sns.FacetGrid(x="NOC", y='Silver', kind="line", ax=ax)
# # sns.regplot(x="NOC", y='Bronze', kind="line", ax=ax)
# plt.ylim(0,16)
# plt.show()
# fig, axs = plt.subplots(ncols=3)
# sns.regplot(x='value', y='wage', data=df_melt, ax=axs[0])
# sns.regplot(x='value', y='wage', data=df_melt, ax=axs[1])
# sns.boxplot(x='education',y='wage', data=df_melt, ax=axs[2])


# from flask import Flask
# app = Flask(__name__)
#
#
# @app.route("/")
# def hello():
#
#     return df[1]
#
#
# if __name__ == "__main__":
#     app.run()


# plt.plot(df['Gold'], countries  )
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-7ba08ab2ee58> in <module>()
#      15 g2  = sns.factorplot(x="NOC",y = 'Silver', data = df[:-1])
#      16 g3 = sns.factorplot(x="NOC",y = 'Bronze', data = df[:-1])
# ---> 17 g = sns.jointplot(g1, g2, kind="line", size=7, space=0)
#      18 sns.factorplot(x='x',y='yModel',data=dataFrame,kind='point')
#      19 #df.plot(x='NOC',y=['Gold','Silver','Bronze'],ax=ax,kind='line')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2239     grid = JointGrid(x, y, data, dropna=dropna,
#    2240                      size=size, ratio=ratio, space=space,
# -> 2241                      xlim=xlim, ylim=ylim)
#    2242
#    2243     # Plot the data using the grid
#
# ...
